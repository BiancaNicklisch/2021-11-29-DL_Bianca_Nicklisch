# %%
import pandas as pd

# %%
x = pd.Series([34, 12, 23, 45])

# %%
print(x)
# Out:
# 0    34
# 1    12
# 2    23
# 3    45
# dtype: int64

# %%
x.dtype
# Out:
# dtype('int64')

# %%
import pandas as pd

# %%
data = {'month': ['Jan', 'Feb', 'Mar'],
        'temp': [-5, 2, 3],
         'below_zero': [True, False, False]}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#   month  temp  below_zero
# 0   Jan    -5        True
# 1   Feb     2       False
# 2   Mar     3       False

# %%
datatypes = df.dtypes

# %%
datatypes
# Out:
# month         object
# temp           int64
# below_zero      bool
# dtype: object

# %%
#Welche Skalenniveau besitzen die Variablen im obigen Beispiel?
month = nominalskaliert
temp = kardinalskaliert
below_zero = nominalskaliert

#Sind die Variablen stetig oder diskret?
month = diskret
temp = stetig
below_zero = diskret

#Was ist der Datentyp jeder einzelnen Spalte?
month = objekt
temp = int64
below_zero = bool

# %%
# Erweitere das Phyton-Dictionary und erstelle eine neue Zeile mit frn Werten ('Apr', 5, False); erstelle eine neue Spalte mit den Werten(2020, 2020, 2020,2020)
new_row = {'month':'Apr', 'temp':5, 'below_zero':False}
df = df.append(new_row, ignore_index=True)
print(df)
# Out:
#   month  temp  below_zero
# 0   Jan    -5        True
# 1   Feb     2       False
# 2   Mar     3       False
# 3   Apr     5       False

# %%
year = ['2020', '2020', '2020', '2020']

# %%
df['year'] = year

# %%
print(df)
# Out:
#   month  temp  below_zero  year
# 0   Jan    -5        True  2020
# 1   Feb     2       False  2020
# 2   Mar     3       False  2020
# 3   Apr     5       False  2020

# %%
import pandas as pd

# %%
df = pd.read_csv("~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage_Small.csv")

# %%
df.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 1               JUVENILE              518               8
# 1                 1               JUVENILE               38               0
# 2                 0                  ADULT               38               4
# 3                 0                  ADULT               48              48
# 4                 1               JUVENILE               28              13
#
#         Age Range Home Library Code Home Library Definition  \
# 0  10 to 19 years                V3       Visitacion Valley
# 1    0 to 9 years                P1                    Park
# 2  10 to 19 years                N4  Noe Valley/Sally Brunn
# 3  20 to 24 years                O7                  Ortega
# 4    0 to 9 years                E9               Excelsior
#
#   Circulation Active Month Circulation Active Year Notice Preference Code  \
# ...

# %%
df.to_json("~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage_Small.json")

# %%
df = pd.read_json("~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage_Small.json")

# %%
df.to_html("~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage_Small.html")

# %%
df_list = pd.read_html("~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage_Small.html")

# %%
df_list[0]
# Out:
#     Unnamed: 0  Patron Type Code Patron Type Definition  Total Checkouts  \
# 0            0                 1               JUVENILE              518
# 1            1                 1               JUVENILE               38
# 2            2                 0                  ADULT               38
# 3            3                 0                  ADULT               48
# 4            4                 1               JUVENILE               28
# 5            5                 1               JUVENILE                1
# 6            6                 1               JUVENILE              293
# 7            7                 1               JUVENILE              900
# 8            8                 1               JUVENILE             1569
# 9            9                 1               JUVENILE               45
# 10          10                 1               JUVENILE                0
# 11          11                 1               JUVENILE               73
# ...

# %%
df = pd.DataFrame(df_list[0])

# %%
df.to_excel("~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage_Small.xlsx")

# %%
df = pd.read_excel("~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage_Small.xlsx")

# %%
df.to_csv("~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage_Small_new.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Patron Type Code Patron Type Definition  \
# 0           0             0                 1               JUVENILE
# 1           1             1                 1               JUVENILE
# 2           2             2                 0                  ADULT
# 3           3             3                 0                  ADULT
# 4           4             4                 1               JUVENILE
#
#    Total Checkouts  Total Renewals       Age Range Home Library Code  \
# 0              518               8  10 to 19 years                V3
# 1               38               0    0 to 9 years                P1
# 2               38               4  10 to 19 years                N4
# 3               48              48  20 to 24 years                O7
# 4               28              13    0 to 9 years                E9
#
#   Home Library Definition Circulation Active Month Circulation Active Year  \
# ...

# %%
# Vergleiche Sie die originale .csv Version mit der Version, nach der Datenrundreise. Ist alles gleich geblieben?


Nein, es sind neue Spalten (Unnamed:0, Unnamed: 0.1) dazu gekommen.

# %%
#   Finde heraus, wie viel freier Arbeitsspeicher Dein Computer hat (Das Betriebssystem und Hintergrundprogramme verbrauchen auch RAM).

(base) nickli@nickli-VirtualBox:~$ free -b # Ausgabe in Byte
              gesamt      belegt     frei     gemeinsam    Zwischen   verfügbar
Speicher:  4116959232  2269851648   132382720    64593920  1714724864  1513918464
Auslager:  1964396544    40353792  1924042752

Wie viele int64 Werte, also Zahlen, die 8 Byte (=64 Bit) Speicher benötigen, kannst Du damit theoretisch in den Arbeitsspeicher laden?

Wenn ich mich auf den noch "frei" Wert im Speicher konzentriere, dann kann ich 16547840 int64 in meinen Arbeitsspeicher laden.

Wie viele Beobachtungen kann eine Tabelle mit 100 numerischen Variablen damit maximal theoretisch haben, damit Du diese noch bearbeiten kannst?

Eine Tabelle kann mit 100 numerischen Variablen damit maximal 165478 Beobachtungen haben damit man sie noch bearbeiten kann.

# %%
import pandas as pd

# %%
df = pd.read_csv("~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage_Small.csv")

# %%
df.memory_usage()
# Out:
# Index                           128
# Patron Type Code                160
# Patron Type Definition          160
# Total Checkouts                 160
# Total Renewals                  160
# Age Range                       160
# Home Library Code               160
# Home Library Definition         160
# Circulation Active Month        160
# Circulation Active Year         160
# Notice Preference Code          160
# Notice Preference Definition    160
# Provided Email Address           20
# Year Patron Registered          160
# Outside of County                20
# Supervisor District             160
# dtype: int64

# %%
df.memory_usage(deep=True)
# Out:
# Index                            128
# Patron Type Code                 160
# Patron Type Definition          1290
# Total Checkouts                  160
# Total Renewals                   160
# Age Range                       1404
# Home Library Code               1178
# Home Library Definition         1346
# Circulation Active Month        1238
# Circulation Active Year         1220
# Notice Preference Code          1160
# Notice Preference Definition    1240
# Provided Email Address            20
# Year Patron Registered           160
# Outside of County                 20
# Supervisor District              160
# dtype: int64

# %%
import pandas as pd

# %%
df = pd.read_csv("~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage.csv")

# %%
df.columns
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Outside of County', 'Supervisor District'],
#       dtype='object')

# %%
x = df['Total Renewals']
df[['Total Renewals', 'Total Checkouts']]
column_names = ['Total Renewals', 'Total Checkouts'] # auxiliary variable
subset = df[column_names]
print(x)
print(subset)
# Out:
# 0          0
# 1         22
# 2          0
# 3          0
# 4         11
#           ..
# 423443    13
# 423444    11
# 423445    58
# 423446     0
# 423447     0
# Name: Total Renewals, Length: 423448, dtype: int64
#         Total Renewals  Total Checkouts
# 0                    0                0
# 1                   22               31
# 2                    0                0
# 3                    0                0
# 4                   11              126
# ...                ...              ...
# 423443              13              291
# 423444              11               15
# 423445              58              208
# 423446               0               26
# 423447               0                0
#
# [423448 rows x 2 columns]

# %%
df['dummy_variable'] = 5

# %%
import numpy as np

df['is_adult'] = df['Patron Type Definition'] == 'ADULT'
df['log_renewals'] = np.log(df['Total Renewals'] + 1)

# %%
df['Circulation Active Year'] = pd.to_numeric(
  df['Circulation Active Year'], errors='coerce'
)

# %%
df['Circulation Active Month'] = pd.to_datetime(
    df['Circulation Active Month'],
    errors='coerce',
    format="%B"
)

# %%
df['Circulation Active Month'] = df['Circulation Active Month'].dt.month

# %%
df['Membership Duration'] = (df['Circulation Active Year'] - df['Year Patron Registered'])*12 + df['Circulation Active Month']
df['Membership Duration']
# Out:
# 0           NaN
# 1          76.0
# 2           NaN
# 3           NaN
# 4         157.0
#           ...
# 423443     75.0
# 423444      7.0
# 423445     31.0
# 423446    148.0
# 423447      NaN
# Name: Membership Duration, Length: 423448, dtype: float64

# %%
df['Membership Duration'] = df['Membership Duration'].fillna(0)

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
import pandas as pd
df = pd.read_csv("~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage.csv")
df.loc[df['Total Checkouts'] > 10000]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 851                    9                SPECIAL            18064
# 1963                   0                  ADULT            10521
# 3499                   0                  ADULT            12740
# 20042                  3                 SENIOR            16060
# 31315                  0                  ADULT            13784
# 39585                  0                  ADULT            11086
# 57239                  0                  ADULT            10906
# 86662                  3                 SENIOR            11748
# 117628                 0                  ADULT            11817
# 120604                 3                 SENIOR            10108
# 129341                 3                 SENIOR            12757
# 138351                 0                  ADULT            10809
# 145600                 3                 SENIOR            11871
# ...

# %%
row_filter = df['Total Checkouts'] > 10000
df.loc[row_filter]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 851                    9                SPECIAL            18064
# 1963                   0                  ADULT            10521
# 3499                   0                  ADULT            12740
# 20042                  3                 SENIOR            16060
# 31315                  0                  ADULT            13784
# 39585                  0                  ADULT            11086
# 57239                  0                  ADULT            10906
# 86662                  3                 SENIOR            11748
# 117628                 0                  ADULT            11817
# 120604                 3                 SENIOR            10108
# 129341                 3                 SENIOR            12757
# 138351                 0                  ADULT            10809
# 145600                 3                 SENIOR            11871
# ...

# %%
row_filter = (df['Patron Type Definition'] == 'SENIOR') & (df['Notice Preference Definition'] == 'email')
df.loc[row_filter]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 5                      3                 SENIOR                0
# 62                     3                 SENIOR              193
# 176                    3                 SENIOR                7
# 260                    3                 SENIOR              341
# 294                    3                 SENIOR               67
# ...                  ...                    ...              ...
# 423359                 3                 SENIOR                4
# 423388                 3                 SENIOR               25
# 423403                 3                 SENIOR              458
# 423405                 3                 SENIOR              280
# 423431                 3                 SENIOR                0
#
#         Total Renewals          Age Range Home Library Code  \
# 5                    0     65 to 74 years                C2
# 62                  90     65 to 74 years                A5
# ...

# %%
filter1 = (df['Total Checkouts'] >= 20) & (df['Total Checkouts'] <= 80)
filter2 =  df['Total Checkouts'].between(20, 80)
all(filter1 == filter2)
# Out:
# True

# %%
df.loc[df['Age Range'] == '0 to 9 years'].shape[0]
# Out:
# 38242

# %%
df.loc[df['Total Checkouts'] > 20000].shape[0]
# Out:
# 3

# %%
df.loc[df['Supervisor District'].isin([1, 2, 3])].shape[0]
# Out:
# 70091

# %%
df.loc[df['Membership Duration'] == '0'].shape[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Membership Duration'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Aufgabe 2.6

#    Filtere den Datensatz nach Kindern unter 10 Jahren. Wie viele Einträge erhältst Du?
Ich erhalte 38242 Kinder

#Gibt es Personen mit mehr als 20000 Ausleihen?
Es sind 3 Personen, die mehr als 20000 AUsleihen haben.

#Wie viele Personen stammen aus dem Norden San Franciscos (Supervisor Districts) 1, 2 und 3)? Nutze die Funktion Series.isin().
    Es stammen 70091 Personden aus dem Norden Sant Franciscos

#Wie viele Prozent der Beobachtungen haben eine Membership Duration von Null Monaten?

Konnte ich leider nicht herausfinden da es allem anschein nach keine Membership Duration in dieser Tabelle gibt.

# %%
import pandas as pd

df = pd.read_csv("~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage.csv")
df['Circulation Active Year']
# Out:
# 0         None
# 1         2016
# 2         None
# 3         None
# 4         2016
#           ...
# 423443    2015
# 423444    2016
# 423445    2016
# 423446    2015
# 423447    None
# Name: Circulation Active Year, Length: 423448, dtype: object

# %%
df = pd.read_csv("~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage.csv", na_values="None")
df['Circulation Active Year']
# Out:
# 0            NaN
# 1         2016.0
# 2            NaN
# 3            NaN
# 4         2016.0
#            ...
# 423443    2015.0
# 423444    2016.0
# 423445    2016.0
# 423446    2015.0
# 423447       NaN
# Name: Circulation Active Year, Length: 423448, dtype: float64

# %%
df = pd.read_csv("~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage.csv", na_values="None")
df['Circulation Active Year'] = pd.to_numeric(df['Circulation Active Year'], errors='coerce')
df['Circulation Active Year']
# Out:
# 0            NaN
# 1         2016.0
# 2            NaN
# 3            NaN
# 4         2016.0
#            ...
# 423443    2015.0
# 423444    2016.0
# 423445    2016.0
# 423446    2015.0
# 423447       NaN
# Name: Circulation Active Year, Length: 423448, dtype: float64

# %%
a= None
b= "None"
print(type(a))
# Out:
# <class 'NoneType'>

# %%
print(type(b))
# Out:
# <class 'str'>

# %%
c= 5
d= "5"
print(type(c))
# Out:
# <class 'int'>

# %%
print(type(d))
# Out:
# <class 'str'>

# %%
e= True
f= "True"
print(type(e))
print(type(f))
# Out:
# <class 'bool'>
# <class 'str'>

# %%
#Aufgabe 2.7 

#Was unterscheidet den Wert None vom Wert "None"? Was den Wert 5 vom Wert "5"? Was den Wert "NaN" vom Wert NaN? Ist True und "True" das glei
None = NoneType 
"None" = ein String 
5 = int 
"5" = ein String
"NaN" = ein String 
NaN =Null Variable 
Nein ist es nicht True ist boolscher Operator und "True" ist String.

# %%
import pandas as pd

df = pd.read_csv("~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage.csv")
df['Circulation Active Year']
# Out:
# 0         None
# 1         2016
# 2         None
# 3         None
# 4         2016
#           ...
# 423443    2015
# 423444    2016
# 423445    2016
# 423446    2015
# 423447    None
# Name: Circulation Active Year, Length: 423448, dtype: object

# %%
df[df['Age Range'].isna()]
df[df['Age Range'].notna()]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
df.isna().sum()
# Out:
# Patron Type Code                     0
# Patron Type Definition               0
# Total Checkouts                      0
# Total Renewals                       0
# Age Range                          215
# Home Library Code                   40
# Home Library Definition              0
# Circulation Active Month             0
# Circulation Active Year              0
# Notice Preference Code               0
# Notice Preference Definition         0
# Provided Email Address               0
# Year Patron Registered               0
# Outside of County                    0
# Supervisor District             110310
# dtype: int64

# %%
df.dropna()
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# 6                      0                  ADULT             3002
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
df['Age Range'].dropna()
# Out:
# 0         20 to 24 years
# 1         25 to 34 years
# 2         45 to 54 years
# 3         25 to 34 years
# 4         45 to 54 years
#                ...
# 423443    10 to 19 years
# 423444    60 to 64 years
# 423445      0 to 9 years
# 423446    10 to 19 years
# 423447      0 to 9 years
# Name: Age Range, Length: 423233, dtype: object

# %%
df['Age Range'].fillna("keine Angabe")
# Out:
# 0         20 to 24 years
# 1         25 to 34 years
# 2         45 to 54 years
# 3         25 to 34 years
# 4         45 to 54 years
#                ...
# 423443    10 to 19 years
# 423444    60 to 64 years
# 423445      0 to 9 years
# 423446    10 to 19 years
# 423447      0 to 9 years
# Name: Age Range, Length: 423448, dtype: object

# %%
df.isna().sum()
# Out:
# Patron Type Code                     0
# Patron Type Definition               0
# Total Checkouts                      0
# Total Renewals                       0
# Age Range                          215
# Home Library Code                   40
# Home Library Definition              0
# Circulation Active Month             0
# Circulation Active Year              0
# Notice Preference Code               0
# Notice Preference Definition         0
# Provided Email Address               0
# Year Patron Registered               0
# Outside of County                    0
# Supervisor District             110310
# dtype: int64

# %%
df = pd.read_csv("~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage.csv", na_values="None")
df2 = df.dropna()
df2.isna().sum()
# Out:
# Patron Type Code                0
# Patron Type Definition          0
# Total Checkouts                 0
# Total Renewals                  0
# Age Range                       0
# Home Library Code               0
# Home Library Definition         0
# Circulation Active Month        0
# Circulation Active Year         0
# Notice Preference Code          0
# Notice Preference Definition    0
# Provided Email Address          0
# Year Patron Registered          0
# Outside of County               0
# Supervisor District             0
# dtype: int64

# %%
#Aufgabe 2.8

#Welche Spalten enthalten alles fehlende Werte?

Folgende Spalten fehlen:
Age Range
Home Library Code
Supervisor District

#Wie viele Beobachtungen wurden dabei entfernt?
Es wurden dabei 148321 Beobachtungen entfernt.

# %%
df2.to_csv('~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage_Clean.csv')

# %%
df.shape[0] - df2.shape[0]
# Out:
# 148321

# %%
import pandas as pd
df = pd.read_csv("~/2021-11-29-DL_Bianca_Nicklisch/Modul_3/data/Library_Usage_Clean.csv")
df.head(100)
# Out:
#     Unnamed: 0  Patron Type Code Patron Type Definition  Total Checkouts  \
# 0            1                 0                  ADULT               31
# 1            4                 0                  ADULT              126
# 2            6                 0                  ADULT             3002
# 3            7                 0                  ADULT                4
# 4            8                 0                  ADULT               20
# ..         ...               ...                    ...              ...
# 95         211                 0                  ADULT               77
# 96         212                 0                  ADULT             1805
# 97         218                 0                  ADULT               21
# 98         219                 0                  ADULT                1
# 99         223                 0                  ADULT                8
#
#     Total Renewals       Age Range Home Library Code Home Library Definition  \
# ...

# %%
df.describe(include='all')
# Out:
#            Unnamed: 0  Patron Type Code Patron Type Definition  \
# count   275127.000000     275127.000000                 275127
# unique            NaN               NaN                     18
# top               NaN               NaN                  ADULT
# freq              NaN               NaN                 172586
# mean    219235.822722          0.941896                    NaN
# std     123808.835178          3.897485                    NaN
# min          1.000000          0.000000                    NaN
# 25%     111231.500000          0.000000                    NaN
# 50%     222881.000000          0.000000                    NaN
# 75%     329033.500000          1.000000                    NaN
# max     423446.000000        104.000000                    NaN
#
#         Total Checkouts  Total Renewals       Age Range Home Library Code  \
# count     275127.000000   275127.000000          275127            275127
# ...

# %%
print(df.min())
print(df['Total Renewals'].min())
# Out:
# Unnamed: 0                                 1
# Patron Type Code                           0
# Patron Type Definition                 ADULT
# Total Checkouts                            0
# Total Renewals                             0
# Age Range                       0 to 9 years
# Home Library Code                         A5
# Home Library Definition                 Anza
# Circulation Active Month               April
# Circulation Active Year               2003.0
# Notice Preference Code                     -
# Notice Preference Definition           email
# Provided Email Address                 False
# Year Patron Registered                  2003
# Outside of County                      False
# Supervisor District                      1.0
# dtype: object
# 0

# %%
df['Total Renewals'].sum()
df['Total Renewals'].between(100, 200).sum()
# Out:
# 17374

# %%
df.columns
df.dtypes
df.shape
# Out:
# (275127, 16)
