# %%
import urllib.request
import pandas as pd

# %%
openapc_url = "https://raw.githubusercontent.com/OpenAPC/openapc-de/master/data/fuberlin/APC_FU_Berlin_2015.csv"

apc_file = "openapc.cvs"

# %%
urllib.request.urlretrieve(openapc_url, apc_file)
# Out:
# ('openapc.cvs', <http.client.HTTPMessage at 0x7f0200583ee0>)

# %%
apcs = pd.read_csv(apc_file)

# %%
apcs
# Out:
#    institution  period     euro                           doi  is_hybrid  \
# 0    FU Berlin    2015  2000.00         10.1038/npjqi.2015.10      False
# 1    FU Berlin    2015  1503.12     10.1103/PhysRevX.5.041008      False
# 2    FU Berlin    2015  2000.00            10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.00  10.1371/journal.ppat.1005246      False
# 4    FU Berlin    2015  1805.00     10.1186/s13099-015-0075-z      False
# ..         ...     ...      ...                           ...        ...
# 56   FU Berlin    2015  1731.45     10.1186/s13015-014-0028-y      False
# 57   FU Berlin    2015  1600.00      10.3389/fpsyg.2015.00194      False
# 58   FU Berlin    2015   219.84       10.3389/fevo.2015.00020      False
# 59   FU Berlin    2015  1386.35             10.1038/srep19416      False
# 60   FU Berlin    2015  2000.00           10.1155/2015/569512      False
#
#                            publisher                  journal_full_title  \
# ...

# %%
apcs.shape
# Out:
# (61, 17)

# %%
apcs.columns
# Out:
# Index(['institution', 'period', 'euro', 'doi', 'is_hybrid', 'publisher',
#        'journal_full_title', 'issn', 'issn_print', 'issn_electronic',
#        'license_ref', 'indexed_in_crossref', 'pmid', 'pmcid', 'ut', 'url',
#        'doaj'],
#       dtype='object')

# %%
apcs["euro"]
# Out:
# 0     2000.00
# 1     1503.12
# 2     2000.00
# 3     2000.00
# 4     1805.00
#        ...
# 56    1731.45
# 57    1600.00
# 58     219.84
# 59    1386.35
# 60    2000.00
# Name: euro, Length: 61, dtype: float64

# %%
apcs ["euro"].min()
# Out:
# 219.84

# %%
apcs ["euro"].max()
# Out:
# 2000.0

# %%
apcs ["euro"].mean()
# Out:
# 1419.6080327868851

# %%
apcs ["euro"].describe()
# Out:
# count      61.000000
# mean     1419.608033
# std       456.811349
# min       219.840000
# 25%      1178.420000
# 50%      1410.070000
# 75%      1800.000000
# max      2000.000000
# Name: euro, dtype: float64

# %%
? apcs

# %%
apcs["euro"] >= 2000
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4     False
#       ...
# 56    False
# 57    False
# 58    False
# 59    False
# 60     True
# Name: euro, Length: 61, dtype: bool

# %%
apcs["euro"]
# Out:
# 0     2000.00
# 1     1503.12
# 2     2000.00
# 3     2000.00
# 4     1805.00
#        ...
# 56    1731.45
# 57    1600.00
# 58     219.84
# 59    1386.35
# 60    2000.00
# Name: euro, Length: 61, dtype: float64

# %%
apcs[ apcs["euro"] >= 2000]
# Out:
#    institution  period    euro                            doi  is_hybrid  \
# 0    FU Berlin    2015  2000.0          10.1038/npjqi.2015.10      False
# 2    FU Berlin    2015  2000.0             10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.0   10.1371/journal.ppat.1005246      False
# 12   FU Berlin    2015  2000.0       10.3389/fpsyg.2015.01675      False
# 15   FU Berlin    2015  2000.0   10.1371/journal.ppat.1004781      False
# 23   FU Berlin    2015  2000.0         10.1127/metz/2015/0641      False
# 28   FU Berlin    2015  2000.0       10.3389/fnhum.2015.00551      False
# 29   FU Berlin    2015  2000.0             10.1038/ncomms8606      False
# 32   FU Berlin    2015  2000.0      10.1186/s12918-015-0183-x      False
# 45   FU Berlin    2015  2000.0   10.1371/journal.pcbi.1004200      False
# 60   FU Berlin    2015  2000.0            10.1155/2015/569512      False
#
#                            publisher               journal_full_title  \
# ...

# %%
apcs[["euro", "publisher"]]
# Out:
#        euro                         publisher
# 0   2000.00                   Springer Nature
# 1   1503.12   American Physical Society (APS)
# 2   2000.00                   Springer Nature
# 3   2000.00  Public Library of Science (PLoS)
# 4   1805.00                   Springer Nature
# ..      ...                               ...
# 56  1731.45                   Springer Nature
# 57  1600.00                Frontiers Media SA
# 58   219.84                Frontiers Media SA
# 59  1386.35                   Springer Nature
# 60  2000.00    Hindawi Publishing Corporation
#
# [61 rows x 2 columns]

# %%
apcs["euro"].hist()
# Out:
# <AxesSubplot:>

# %%
apcs[(apcs["euro"] >= 750) & (apcs["euro"] <= 950)]
# Out:
#    institution  period    euro                       doi  is_hybrid  \
# 16   FU Berlin    2015  892.50     10.4081/ejh.2015.2516      False
# 38   FU Berlin    2015  895.15       10.1155/2015/235184      False
# 39   FU Berlin    2015  853.84     10.4236/me.2015.66072      False
# 43   FU Berlin    2015  770.00  10.3389/fpsyg.2015.00714      False
#
#                                publisher                  journal_full_title  \
# 16                PAGEPress Publications  European Journal of Histochemistry
# 38        Hindawi Publishing Corporation                         Scientifica
# 39  Scientific Research Publishing, Inc,                      Modern Economy
# 43                    Frontiers Media SA             Frontiers in Psychology
#
#          issn issn_print issn_electronic  \
# 16  2038-8306  1121-760X       2038-8306
# 38  2090-908X        NaN       2090-908X
# 39  2152-7245  2152-7245       2152-7261
# 43  1664-1078        NaN       1664-1078
#
# ...

# %%
apcs["euro"].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
apcs["euro"].hist(bins=20, color= "orange")
# Out:
# <AxesSubplot:>

# %%
apcs ["publisher"]
# Out:
# 0                      Springer Nature
# 1      American Physical Society (APS)
# 2                      Springer Nature
# 3     Public Library of Science (PLoS)
# 4                      Springer Nature
#                     ...
# 56                     Springer Nature
# 57                  Frontiers Media SA
# 58                  Frontiers Media SA
# 59                     Springer Nature
# 60      Hindawi Publishing Corporation
# Name: publisher, Length: 61, dtype: object

# %%
apcs [apcs["publisher"] == "Springer Nature"]
# Out:
#    institution  period     euro                        doi  is_hybrid  \
# 0    FU Berlin    2015  2000.00      10.1038/npjqi.2015.10      False
# 2    FU Berlin    2015  2000.00         10.1038/ncomms9498      False
# 4    FU Berlin    2015  1805.00  10.1186/s13099-015-0075-z      False
# 13   FU Berlin    2015  1165.00          10.1038/srep11598      False
# 14   FU Berlin    2015  1386.35          10.1038/srep12681      False
# 24   FU Berlin    2015  1249.50  10.1186/s13570-015-0035-8      False
# 25   FU Berlin    2015  1625.00  10.1186/s13071-015-0924-0      False
# 26   FU Berlin    2015  1800.00  10.1186/s12862-015-0390-5      False
# 29   FU Berlin    2015  2000.00         10.1038/ncomms8606      False
# 32   FU Berlin    2015  2000.00  10.1186/s12918-015-0183-x      False
# 54   FU Berlin    2015  1969.45  10.1186/s12917-015-0351-7      False
# 56   FU Berlin    2015  1731.45  10.1186/s13015-014-0028-y      False
# ...

# %%
apcs [["institution", "period", "doi", "issn"]  ["publisher"]]
# Out:
# <>:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <>:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# /tmp/ipykernel_53784/796019362.py:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   apcs [["institution", "period", "doi", "issn"]  ["publisher"]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_53784/796019362.py in <module>
# ----> 1 apcs [["institution", "period", "doi", "issn"]  ["publisher"]]
#
# TypeError: list indices must be integers or slices, not str

# %%
apcs [(apcs["publisher"] == "Springer Nature")][("institution", "period", "doi", "issn")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('institution', 'period', 'doi', 'issn')
#
# The above exception was the direct cause of the following exception:
#
# ...
