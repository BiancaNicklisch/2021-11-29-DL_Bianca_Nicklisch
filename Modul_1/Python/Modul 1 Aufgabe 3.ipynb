# %%
import urllib.request
import pandas as pd

# %%
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2018&$limit=10000"
checkout_file = "checkout.csv"
urllib.request.urlretrieve(url, checkout_file)
# Out:
# ('checkout.csv', <http.client.HTTPMessage at 0x7f24f9b15320>)

# %%
checkouts_df = pd.read_csv(checkout_file)

# %%
checkouts_df
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0       Digital    OverDrive        EBOOK          2018              1
# 1       Digital       Hoopla   TELEVISION          2018              1
# 2      Physical      Horizon    SOUNDDISC          2018              1
# 3       Digital    OverDrive        EBOOK          2018              1
# 4       Digital    OverDrive        EBOOK          2018              1
# ...         ...          ...          ...           ...            ...
# 9995    Digital    OverDrive    AUDIOBOOK          2018              1
# 9996    Digital    OverDrive        EBOOK          2018              1
# 9997   Physical      Horizon         BOOK          2018              1
# 9998   Physical      Horizon         BOOK          2018              1
# 9999    Digital    OverDrive    AUDIOBOOK          2018              1
#
#       checkouts                                              title  \
# ...

# %%
checkouts_df["publicationyear"].hist(bins=20, color= "red")
# Out:
# <AxesSubplot:>

# %%
checkouts_df[checkouts_df["creator"] == "Agatha Christie"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 31      Digital    OverDrive        EBOOK          2018              3
# 48      Digital    OverDrive        EBOOK          2018             11
# 986     Digital    OverDrive        EBOOK          2018              1
# 1080    Digital    OverDrive    AUDIOBOOK          2018              1
# 1962    Digital    OverDrive        EBOOK          2018              1
# 2393    Digital    OverDrive        EBOOK          2018              1
# 3903    Digital    OverDrive    AUDIOBOOK          2018              1
# 4936    Digital    OverDrive    AUDIOBOOK          2018              1
# 5451    Digital    OverDrive        EBOOK          2018              1
# 5662    Digital    OverDrive        EBOOK          2018              1
# 7034    Digital    OverDrive        EBOOK          2018              1
# 7913    Digital    OverDrive        EBOOK          2018              1
# ...

# %%
checkouts_df[checkouts_df["checkouttype"] == "Horizon"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 2      Physical      Horizon    SOUNDDISC          2018              1
# 7      Physical      Horizon         BOOK          2018              2
# 20     Physical      Horizon         BOOK          2018              3
# 22     Physical      Horizon    SOUNDDISC          2018              3
# 25     Physical      Horizon         BOOK          2018              3
# ...         ...          ...          ...           ...            ...
# 9991   Physical      Horizon         BOOK          2018              1
# 9992   Physical      Horizon    SOUNDDISC          2018              1
# 9993   Physical      Horizon         BOOK          2018              1
# 9997   Physical      Horizon         BOOK          2018              1
# 9998   Physical      Horizon         BOOK          2018              1
#
#       checkouts                                              title  \
# ...

# %%
checkouts_df[["title", "creator"]]
# Out:
#                                                   title  \
# 0                                    Enemy of the State
# 1        Newspaper Mom / Cucumber in Rio / Donut Raffle
# 2                                 Mono / the Mavericks.
# 3                                         Anna Karenina
# 4                           Dragon: Vlad Series, Book 8
# ...                                                 ...
# 9995  Cooking for Picasso: A Novel (unabridged) (Una...
# 9996                        The Book of Summer: A Novel
# 9997                            Revival / Stephen King.
# 9998  Loula is leaving for Africa / written and illu...
# 9999                  The Story About Ping (Unabridged)
#
#                         creator
# 0                   Vince Flynn
# 1                           NaN
# 2     Mavericks (Musical group)
# 3                   Leo Tolstoy
# 4                  Steven Brust
# ...                         ...
# 9995             Camille Aubray
# ...
